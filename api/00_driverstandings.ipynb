# %%
import pandas as pd
import numpy as np
import requests
from sqlalchemy import create_engine
import json

# %%
f = open(r'C:\Users\henri\OneDrive\ProjetosDS\F1\keys.json')
my_keys = json.load(f)

# %%
usuario = my_keys['user']
senha = my_keys['password']

# %%
engine = create_engine(f'mysql://{usuario}:{senha}@localhost:3306/F1')

# %%
ListaDados = []

c = 1950
#d = 18

ano_final = now.year

while c <= ano_final:
    d = 1
    while True:
        path = f'http://ergast.com/api/f1/{c}/{d}/driverStandings.json?limit=1000'
        resp = requests.get(path)
        json = resp.json()

        if len(json['MRData']['StandingsTable']['StandingsLists']) == 0:
            break
        DFx = json['MRData']['StandingsTable']['StandingsLists'][0]
        season = DFx['season']
        Round1 = DFx['round']
        for itens in DFx['DriverStandings']:
            driver = itens['Driver']['driverId']
            position = itens['position']
            points = itens['points']
            wins = itens['wins']

            prov_data = {
                'season':season,
                'round':Round1,
                'driver': driver,
                'position':position,
                'points':points,
                'wins':wins
            }
            ListaDados.append(prov_data)
        print(f'Coletando o ano de {c} e a rodada {d}')   
        d += 1
    c += 1
# Out:
# Coletando o ano de 1950 e a rodada 1
# Coletando o ano de 1950 e a rodada 2
# Coletando o ano de 1950 e a rodada 3
# Coletando o ano de 1950 e a rodada 4
# Coletando o ano de 1950 e a rodada 5
# Coletando o ano de 1950 e a rodada 6
# Coletando o ano de 1950 e a rodada 7
# Coletando o ano de 1951 e a rodada 1
# Coletando o ano de 1951 e a rodada 2
# Coletando o ano de 1951 e a rodada 3
# Coletando o ano de 1951 e a rodada 4
# Coletando o ano de 1951 e a rodada 5
# Coletando o ano de 1951 e a rodada 6
# Coletando o ano de 1951 e a rodada 7
# Coletando o ano de 1951 e a rodada 8
# Coletando o ano de 1952 e a rodada 1
# Coletando o ano de 1952 e a rodada 2
# Coletando o ano de 1952 e a rodada 3
# Coletando o ano de 1952 e a rodada 4
# Coletando o ano de 1952 e a rodada 5
# Coletando o ano de 1952 e a rodada 6
# Coletando o ano de 1952 e a rodada 7
# Coletando o ano de 1952 e a rodada 8
# Coletando o ano de 1953 e a rodada 1
# Coletando o ano de 1953 e a rodada 2
# ...

# %%
df4 = pd.DataFrame(ListaDados)
df4
# Out:
#       season round          driver position points wins
# 0       1950     1          farina        1      9    1
# 1       1950     1         fagioli        2      6    0
# 2       1950     1     reg_parnell        3      4    0
# 3       1950     1       cabantous        4      3    0
# 4       1950     1          rosier        5      2    0
# ...      ...   ...             ...      ...    ...  ...
# 33430   2022     1          stroll       16      0    0
# 33431   2022     1         tsunoda       17      0    0
# 33432   2022     1  max_verstappen       18      0    0
# 33433   2022     1          vettel       19      0    0
# 33434   2022     1            zhou       20      0    0
#
# [33435 rows x 6 columns]

# %%
df4.to_sql('driver_standings', engine, if_exists='replace', index=False)
